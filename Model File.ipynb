# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing and Reading Combined Data

# %%
df = pd.read_csv('combined.csv')
df
# Out:
#      latitude   longitude  blk_no            road_name  postal_code  \
# 0    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# 1    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# 2    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# 3    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# 4    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# ..        ...         ...     ...                  ...          ...
# 773  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
# 774  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
# 775  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
# 776  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
# 777  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
#
#                   address      cbd_dist  min_dist_mrt    month        town  \
# 0    174 ANG MO KIO AVE 4  13339.584230           0.0  2015-01  ANG MO KIO
# 1    174 ANG MO KIO AVE 4  13339.584230           0.0  2015-12  ANG MO KIO
# 2    174 ANG MO KIO AVE 4  13339.584230           0.0  2016-05  ANG MO KIO
# 3    174 ANG MO KIO AVE 4  13339.584230           0.0  2016-06  ANG MO KIO
# 4    174 ANG MO KIO AVE 4  13339.584230           0.0  2016-11  ANG MO KIO
# ..                    ...           ...           ...      ...         ...
# 773  428 ANG MO KIO AVE 3  17255.243341           0.0  2015-02  ANG MO KIO
# 774  428 ANG MO KIO AVE 3  17255.243341           0.0  2015-07  ANG MO KIO
# 775  428 ANG MO KIO AVE 3  17255.243341           0.0  2015-08  ANG MO KIO
# 776  428 ANG MO KIO AVE 3  17255.243341           0.0  2016-10  ANG MO KIO
# 777  428 ANG MO KIO AVE 3  17255.243341           0.0  2016-12  ANG MO KIO
#
#     flat_type  block       street_name storey_range  floor_area_sqm  \
# 0      3 ROOM    174  ANG MO KIO AVE 4     07 TO 09            60.0
# 1      3 ROOM    174  ANG MO KIO AVE 4     10 TO 12            60.0
# 2      3 ROOM    174  ANG MO KIO AVE 4     04 TO 06            69.0
# 3      2 ROOM    174  ANG MO KIO AVE 4     07 TO 09            45.0
# 4      3 ROOM    174  ANG MO KIO AVE 4     04 TO 06            61.0
# ..        ...    ...               ...          ...             ...
# 773    4 ROOM    428  ANG MO KIO AVE 3     04 TO 06            92.0
# 774    4 ROOM    428  ANG MO KIO AVE 3     01 TO 03            92.0
# 775    4 ROOM    428  ANG MO KIO AVE 3     07 TO 09            92.0
# 776    4 ROOM    428  ANG MO KIO AVE 3     10 TO 12            92.0
# 777    4 ROOM    428  ANG MO KIO AVE 3     10 TO 12            92.0
#
#          flat_model  lease_commence_date  remaining_lease  resale_price  \
# 0          Improved                 1986               70      255000.0
# 1          Improved                 1986               69      275000.0
# 2          Improved                 1986               68      310000.0
# 3          Improved                 1986               68      253000.0
# 4          Improved                 1986               68      290000.0
# ..              ...                  ...              ...           ...
# 773  New Generation                 1978               62      485000.0
# 774  New Generation                 1978               62      411000.0
# 775  New Generation                 1978               62      477000.0
# 776  New Generation                 1978               61      490000.0
# 777  New Generation                 1978               60      470000.0
#
#      lease_remain_years
# 0                    62
# 1                    62
# 2                    62
# 3                    62
# 4                    62
# ..                  ...
# 773                  54
# 774                  54
# 775                  54
# 776                  54
# 777                  54
#
# [778 rows x 20 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                 float64
# road_name               object
# postal_code            float64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                    int64
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease          int64
# resale_price           float64
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# lease_remain_years     0
# dtype: int64

# %% [markdown]
# ### Minor Data Preprocessing for Combined Data

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#      latitude   longitude  blk_no            road_name  postal_code  \
# 0    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# 1    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# 2    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# 3    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# 4    1.333153  103.742286   174.0  ANG MO KIO AVENUE 4     560174.0
# ..        ...         ...     ...                  ...          ...
# 773  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
# 774  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
# 775  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
# 776  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
# 777  1.427488  103.792730   428.0  ANG MO KIO AVENUE 3     560428.0
#
#                   address      cbd_dist  min_dist_mrt    month        town  \
# 0    174 ANG MO KIO AVE 4  13339.584230           0.0  2015-01  ANG MO KIO
# 1    174 ANG MO KIO AVE 4  13339.584230           0.0  2015-12  ANG MO KIO
# 2    174 ANG MO KIO AVE 4  13339.584230           0.0  2016-05  ANG MO KIO
# 3    174 ANG MO KIO AVE 4  13339.584230           0.0  2016-06  ANG MO KIO
# 4    174 ANG MO KIO AVE 4  13339.584230           0.0  2016-11  ANG MO KIO
# ..                    ...           ...           ...      ...         ...
# 773  428 ANG MO KIO AVE 3  17255.243341           0.0  2015-02  ANG MO KIO
# 774  428 ANG MO KIO AVE 3  17255.243341           0.0  2015-07  ANG MO KIO
# 775  428 ANG MO KIO AVE 3  17255.243341           0.0  2015-08  ANG MO KIO
# 776  428 ANG MO KIO AVE 3  17255.243341           0.0  2016-10  ANG MO KIO
# 777  428 ANG MO KIO AVE 3  17255.243341           0.0  2016-12  ANG MO KIO
#
#      ... block       street_name storey_range floor_area_sqm      flat_model  \
# 0    ...   174  ANG MO KIO AVE 4     07 TO 09           60.0        Improved
# 1    ...   174  ANG MO KIO AVE 4     10 TO 12           60.0        Improved
# 2    ...   174  ANG MO KIO AVE 4     04 TO 06           69.0        Improved
# 3    ...   174  ANG MO KIO AVE 4     07 TO 09           45.0        Improved
# 4    ...   174  ANG MO KIO AVE 4     04 TO 06           61.0        Improved
# ..   ...   ...               ...          ...            ...             ...
# 773  ...   428  ANG MO KIO AVE 3     04 TO 06           92.0  New Generation
# 774  ...   428  ANG MO KIO AVE 3     01 TO 03           92.0  New Generation
# 775  ...   428  ANG MO KIO AVE 3     07 TO 09           92.0  New Generation
# 776  ...   428  ANG MO KIO AVE 3     10 TO 12           92.0  New Generation
# 777  ...   428  ANG MO KIO AVE 3     10 TO 12           92.0  New Generation
#
#     lease_commence_date  remaining_lease  resale_price  lease_remain_years  \
# 0                  1986               70      255000.0                  62
# 1                  1986               69      275000.0                  62
# 2                  1986               68      310000.0                  62
# 3                  1986               68      253000.0                  62
# 4                  1986               68      290000.0                  62
# ..                  ...              ...           ...                 ...
# 773                1978               62      485000.0                  54
# 774                1978               62      411000.0                  54
# 775                1978               62      477000.0                  54
# 776                1978               61      490000.0                  54
# 777                1978               60      470000.0                  54
#
#      storey_median
# 0              8.0
# 1             11.0
# 2              5.0
# 3              8.0
# 4              5.0
# ..             ...
# 773            5.0
# 774            2.0
# 775            8.0
# 776           11.0
# 777           11.0
#
# [778 rows x 21 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#          cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0    13339.584230           0.0            60.0                  62
# 1    13339.584230           0.0            60.0                  62
# 2    13339.584230           0.0            69.0                  62
# 3    13339.584230           0.0            45.0                  62
# 4    13339.584230           0.0            61.0                  62
# ..            ...           ...             ...                 ...
# 773  17255.243341           0.0            92.0                  54
# 774  17255.243341           0.0            92.0                  54
# 775  17255.243341           0.0            92.0                  54
# 776  17255.243341           0.0            92.0                  54
# 777  17255.243341           0.0            92.0                  54
#
#      storey_median  resale_price
# 0              8.0      255000.0
# 1             11.0      275000.0
# 2              5.0      310000.0
# 3              8.0      253000.0
# 4              5.0      290000.0
# ..             ...           ...
# 773            5.0      485000.0
# 774            2.0      411000.0
# 775            8.0      477000.0
# 776           11.0      490000.0
# 777           11.0      470000.0
#
# [778 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#          cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0    13339.584230           0.0            60.0                  62
# 1    13339.584230           0.0            60.0                  62
# 2    13339.584230           0.0            69.0                  62
# 3    13339.584230           0.0            45.0                  62
# 4    13339.584230           0.0            61.0                  62
# ..            ...           ...             ...                 ...
# 773  17255.243341           0.0            92.0                  54
# 774  17255.243341           0.0            92.0                  54
# 775  17255.243341           0.0            92.0                  54
# 776  17255.243341           0.0            92.0                  54
# 777  17255.243341           0.0            92.0                  54
#
#      storey_median  resale_price
# 0              8.0      255000.0
# 1             11.0      275000.0
# 2              5.0      310000.0
# 3              8.0      253000.0
# 4              5.0      290000.0
# ..             ...           ...
# 773            5.0      485000.0
# 774            2.0      411000.0
# 775            8.0      477000.0
# 776           11.0      490000.0
# 777           11.0      470000.0
#
# [766 rows x 6 columns]

# %% [markdown]
# ### Checking and Handling for Skewness in the Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
# Apply a logarithmic transformation to the required columns only.
# One need to apply it and check, in some cases it will handle the skewness, and in other cases it might not have a great 
# effect on the data, so no need to apply for that columns
    
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %%
df2=df1.drop("min_dist_mrt",axis=1)

# %% [markdown]
# ### Visualization among different columns using Correlation Matrix

# %%
import seaborn as sns

corrMatrix = df2.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %%
from sklearn.preprocessing import StandardScaler

X=df2[['cbd_dist','floor_area_sqm','lease_remain_years','storey_median']]
y=df2['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#             0         1         2         3
# 0    0.797430 -2.424780  4.358444  0.377459
# 1    0.797430 -2.424780  4.358444  0.909486
# 2    0.797430 -1.444295  4.358444 -0.407757
# 3    0.797430 -4.442982  4.358444  0.377459
# 4    0.797430 -2.308820  4.358444 -0.407757
# ..        ...       ...       ...       ...
# 761  1.448137  0.573907 -0.495890 -0.407757
# 762  1.448137  0.573907 -0.495890 -1.938565
# 763  1.448137  0.573907 -0.495890  0.377459
# 764  1.448137  0.573907 -0.495890  0.909486
# 765  1.448137  0.573907 -0.495890  0.909486
#
# [766 rows x 4 columns]

# %% [markdown]
# ### Splitting the Data for Training and Testing Purposes

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 22, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2}
#
# Mean squared error: 0.0030554113262010133
# Mean Absolute Error 0.030930861613381672
# Root Mean squared error: 0.05527577522026275
#
# R-squared: 0.9118633905788309

# %% [markdown]
# ### Testing Our Trained Model (Decision Tree Regressor)

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :4])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 572493.6092398935

# %%
# Saving the model
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
